# %% [markdown]
# # Heart Disease Prediction

# %% [markdown]
# ![1800ss_getty_rf_heart.jpeg](attachment:1800ss_getty_rf_heart.jpeg)

# %% [markdown]
# ### Context:
# #### - [Exploratory Data Analysis (EDA)](#EDA)
# #### - [Data Pre-Processing](#PP)
# #### - [Data Modeling](#modeling)

# %%
import pandas as pd
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
sns.set_style('whitegrid')
plt.style.use('seaborn-deep')
plt.style.use('fivethirtyeight')
plt.rcParams['font.family'] = 'Cairo'
plt.rcParams['font.serif'] = 'Cairo-Bold'
plt.rcParams['font.monospace'] = 'Ubuntu Mono'
plt.rcParams['font.size'] = 25
plt.rcParams['axes.labelsize'] = 25
plt.rcParams['axes.titlesize'] = 25
plt.rcParams['xtick.labelsize'] = 18
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['legend.fontsize'] = 18
plt.rcParams['figure.titlesize'] = 14
plt.rcParams['figure.figsize'] = (12, 8)

# %% [markdown]
# <a id = "EDA"> </a>
# ## ● Exploratory Data Analysis (EDA)

# %%
df = pd.read_csv("data/framingham.csv")
df.head(10)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
# 5     0   43        2.0              0         0.0     0.0                0
# 6     0   63        1.0              0         0.0     0.0                0
# 7     0   45        2.0              1        20.0     0.0                0
# 8     1   52        1.0              0         0.0     0.0                0
# 9     1   43        1.0              1        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
# 5             1         0    228.0  180.0  110.0  30.30       77.0     99.0
# 6             0         0    205.0  138.0   71.0  33.11       60.0     85.0
# 7             0         0    313.0  100.0   71.0  21.68       79.0     78.0
# 8             1         0    260.0  141.5   89.0  26.36       76.0     79.0
# 9             1         0    225.0  162.0  107.0  23.61       93.0     88.0
#
#    TenYearCHD
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0
# 5           0
# 6           1
# 7           0
# 8           0
# 9           0

# %%
df.shape
# Out:
# (4240, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4240 non-null   int64
#  1   age              4240 non-null   int64
#  2   education        4135 non-null   float64
#  3   currentSmoker    4240 non-null   int64
#  4   cigsPerDay       4211 non-null   float64
#  5   BPMeds           4187 non-null   float64
#  6   prevalentStroke  4240 non-null   int64
#  7   prevalentHyp     4240 non-null   int64
#  8   diabetes         4240 non-null   int64
#  9   totChol          4190 non-null   float64
#  10  sysBP            4240 non-null   float64
#  11  diaBP            4240 non-null   float64
#  12  BMI              4221 non-null   float64
#  13  heartRate        4239 non-null   float64
#  14  glucose          3852 non-null   float64
#  15  TenYearCHD       4240 non-null   int64
# dtypes: float64(9), int64(7)
# memory usage: 530.1 KB

# %%
df.describe().T
# Out:
#                   count        mean        std     min     25%    50%     75%  \
# male             4240.0    0.429245   0.495027    0.00    0.00    0.0    1.00
# age              4240.0   49.580189   8.572942   32.00   42.00   49.0   56.00
# education        4135.0    1.979444   1.019791    1.00    1.00    2.0    3.00
# currentSmoker    4240.0    0.494104   0.500024    0.00    0.00    0.0    1.00
# cigsPerDay       4211.0    9.005937  11.922462    0.00    0.00    0.0   20.00
# BPMeds           4187.0    0.029615   0.169544    0.00    0.00    0.0    0.00
# prevalentStroke  4240.0    0.005896   0.076569    0.00    0.00    0.0    0.00
# prevalentHyp     4240.0    0.310613   0.462799    0.00    0.00    0.0    1.00
# diabetes         4240.0    0.025708   0.158280    0.00    0.00    0.0    0.00
# totChol          4190.0  236.699523  44.591284  107.00  206.00  234.0  263.00
# sysBP            4240.0  132.354599  22.033300   83.50  117.00  128.0  144.00
# diaBP            4240.0   82.897759  11.910394   48.00   75.00   82.0   90.00
# BMI              4221.0   25.800801   4.079840   15.54   23.07   25.4   28.04
# heartRate        4239.0   75.878981  12.025348   44.00   68.00   75.0   83.00
# glucose          3852.0   81.963655  23.954335   40.00   71.00   78.0   87.00
# TenYearCHD       4240.0    0.151887   0.358953    0.00    0.00    0.0    0.00
#
#                    max
# male               1.0
# age               70.0
# education          4.0
# currentSmoker      1.0
# cigsPerDay        70.0
# BPMeds             1.0
# prevalentStroke    1.0
# prevalentHyp       1.0
# diabetes           1.0
# totChol          696.0
# sysBP            295.0
# diaBP            142.5
# BMI               56.8
# heartRate        143.0
# glucose          394.0
# TenYearCHD         1.0

# %%
df.duplicated().sum()
# No duplicates
# Out:
# 0

# %%
df.isna().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
plt.hist(df['TenYearCHD']);
plt.title("TenYearCHD Distribution");
# Out:
# findfont: Font family ['Cairo'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Cairo'] not found. Falling back to DejaVu Sans.

# %%
plt.rcParams['font.size'] = 12
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['legend.fontsize'] = 12
plt.rcParams['figure.titlesize'] = 12
plt.figure(figsize = (14, 10)) 
sns.heatmap(df.corr(), cmap='Purples',annot=True, linecolor='Green', linewidths=1.0)
plt.title("Corrleation Heatmap")
plt.xticks(rotation=45)
plt.show()
# Out:
# findfont: Font family ['Cairo'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Cairo'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ### Countplot of people based on their sex and whether they are Current Smoker or not

# %%
sns.catplot(data=df, kind='count', x='male',hue='currentSmoker')
plt.show()

# %% [markdown]
# <a id = "PP"> </a>
# # ● Data Pre-Processing

# %%
# plot missing values
def calc_missing(df):
    missing = df.isna().sum().sort_values(ascending=False)
    missing = missing[missing != 0]
    missing_perc = missing/df.shape[0]*100
    return missing, missing_perc

if df.isna().any().sum()>0:
    missing, missing_perc = calc_missing(df)
    missing.plot(kind='bar',figsize=(20,10))
    plt.title('Missing Values')
    plt.xticks(rotation=45)
    plt.show()
else:
    print("No Missing Values")

# %%
# Defining a function to remove nulls
def fixna(col,val):
        print(f"{df[col].value_counts()}")
        print(f"Old No of Nulls: {df[col].isna().sum()}")
        if val.lower() == "mode":
            df[col] = df[col].fillna(df[col].mode()[0])
        elif val.lower() == "mean":
            df[col] = df[col].fillna(df[col].mean())    
        else:
            df[col] = df[col].fillna(val)
        print(f"New No of Nulls: {df[col].isna().sum()}")

# %%
null_cols = [col for col in df.columns if df[col].isna().sum() !=0 ] # Cols with nulls
null_cols
# Out:
# ['education', 'cigsPerDay', 'BPMeds', 'totChol', 'BMI', 'heartRate', 'glucose']

# %%
for col in null_cols:
    print(df[col].value_counts(),end = "\n\n")
# Out:
# 1.0    1720
# 2.0    1253
# 3.0     689
# 4.0     473
# Name: education, dtype: int64
#
# 0.0     2145
# 20.0     734
# 30.0     218
# 15.0     210
# 10.0     143
# 9.0      130
# 5.0      121
# 3.0      100
# 40.0      80
# 1.0       67
# 43.0      56
# 25.0      55
# 35.0      22
# 6.0       18
# 2.0       18
# 7.0       12
# 60.0      11
# 8.0       11
# 4.0        9
# 18.0       8
# 17.0       7
# 50.0       6
# 23.0       6
# 11.0       5
# 16.0       3
# 12.0       3
# 13.0       3
# 45.0       3
# 19.0       2
# 14.0       2
# 70.0       1
# 38.0       1
# 29.0       1
# Name: cigsPerDay, dtype: int64
#
# 0.0    4063
# 1.0     124
# Name: BPMeds, dtype: int64
#
# 240.0    85
# 220.0    70
# 260.0    62
# 210.0    61
# 232.0    59
#          ..
# 432.0     1
# 385.0     1
# 363.0     1
# 362.0     1
# 347.0     1
# Name: totChol, Length: 248, dtype: int64
#
# 22.19    18
# 22.54    18
# 22.91    18
# 23.48    18
# 25.09    16
#          ..
# 35.78     1
# 19.37     1
# 31.29     1
# 34.91     1
# 39.60     1
# Name: BMI, Length: 1364, dtype: int64
#
# 75.0     563
# 80.0     385
# 70.0     305
# 60.0     231
# 85.0     228
#         ...
# 47.0       1
# 44.0       1
# 101.0      1
# 143.0      1
# 46.0       1
# Name: heartRate, Length: 73, dtype: int64
#
# 75.0     193
# 77.0     167
# 73.0     156
# 80.0     153
# 70.0     152
#         ...
# 244.0      1
# 163.0      1
# 270.0      1
# 155.0      1
# 255.0      1
# Name: glucose, Length: 143, dtype: int64

# %%
fixna('education','mode')
# Out:
# 1.0    1720
# 2.0    1253
# 3.0     689
# 4.0     473
# Name: education, dtype: int64
# Old No of Nulls: 105
# New No of Nulls: 0

# %%
fixna('cigsPerDay','mean')
# Out:
# 0.0     2145
# 20.0     734
# 30.0     218
# 15.0     210
# 10.0     143
# 9.0      130
# 5.0      121
# 3.0      100
# 40.0      80
# 1.0       67
# 43.0      56
# 25.0      55
# 35.0      22
# 6.0       18
# 2.0       18
# 7.0       12
# 60.0      11
# 8.0       11
# 4.0        9
# 18.0       8
# 17.0       7
# 50.0       6
# 23.0       6
# 11.0       5
# 16.0       3
# 12.0       3
# 13.0       3
# 45.0       3
# 19.0       2
# 14.0       2
# 70.0       1
# 38.0       1
# 29.0       1
# Name: cigsPerDay, dtype: int64
# Old No of Nulls: 29
# New No of Nulls: 0

# %%
fixna('BPMeds','mode') # mode not mean
# Out:
# 0.0    4063
# 1.0     124
# Name: BPMeds, dtype: int64
# Old No of Nulls: 53
# New No of Nulls: 0

# %%
fixna('totChol','mean')
# Out:
# 240.0    85
# 220.0    70
# 260.0    62
# 210.0    61
# 232.0    59
#          ..
# 432.0     1
# 385.0     1
# 363.0     1
# 362.0     1
# 347.0     1
# Name: totChol, Length: 248, dtype: int64
# Old No of Nulls: 50
# New No of Nulls: 0

# %%
fixna('BMI','mean')
# Out:
# 22.19    18
# 22.54    18
# 22.91    18
# 23.48    18
# 25.09    16
#          ..
# 35.78     1
# 19.37     1
# 31.29     1
# 34.91     1
# 39.60     1
# Name: BMI, Length: 1364, dtype: int64
# Old No of Nulls: 19
# New No of Nulls: 0

# %%
fixna('heartRate','mean')
# Out:
# 75.0     563
# 80.0     385
# 70.0     305
# 60.0     231
# 85.0     228
#         ...
# 47.0       1
# 44.0       1
# 101.0      1
# 143.0      1
# 46.0       1
# Name: heartRate, Length: 73, dtype: int64
# Old No of Nulls: 1
# New No of Nulls: 0

# %%
fixna('glucose','mean')
# Out:
# 75.0     193
# 77.0     167
# 73.0     156
# 80.0     153
# 70.0     152
#         ...
# 244.0      1
# 163.0      1
# 270.0      1
# 155.0      1
# 255.0      1
# Name: glucose, Length: 143, dtype: int64
# Old No of Nulls: 388
# New No of Nulls: 0

# %%
df.isna().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %% [markdown]
# ### <b> Nulls Fixed  😎

# %%
# Making a backup in case anything happened
backup = df

# %%
# boxplots of numerical features for outlier detection
fig = plt.figure(figsize=(16,16))
for i in range(len(df.columns)):
    fig.add_subplot(4, 4, i+1)
    sns.boxplot(y=df.iloc[:,i])
plt.tight_layout()
plt.show()

# %%
df[df['BMI'] >=50]
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 2657     0   55        1.0              0         0.0     0.0
# 3927     0   61        1.0              0         0.0     1.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 2657                0             1         0    208.0  190.0  130.0  56.80
# 3927                1             1         0    225.0  194.0  111.0  51.28
#
#       heartRate  glucose  TenYearCHD
# 2657       90.0     86.0           1
# 3927       80.0    103.0           0

# %%
df.drop(df[df['BMI'] >=50].index,inplace = True)
df[df['BMI'] >=50]
# Out:
# Empty DataFrame
# Columns: [male, age, education, currentSmoker, cigsPerDay, BPMeds, prevalentStroke, prevalentHyp, diabetes, totChol, sysBP, diaBP, BMI, heartRate, glucose, TenYearCHD]
# Index: []

# %% [markdown]
# #### Glucose Level can be up to 400, and that indicates high sugar level in blood
# #### Max of BMI is 50, it cannot be more than 50
# #### Heart Rate can increase to 160 and sometimes more, so outliers here are normal
# #### cholLevel can increase to 800 and sometimes 1000, normal
# #### diaBP is not considered outlier

# %% [markdown]
# <a id = "modeling"> </a>
# # ● Data Modelling

# %% [markdown]
# ## Data Modelling - 1

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split as TTS
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
num_feats = ['age','education','cigsPerDay','totChol','sysBP','diaBP','BMI','heartRate','glucose']

# %%
df = df.sample(frac = 1) # Shuffling the records

# %%
x = df.iloc[:,0:-1]
y = df.iloc[:,-1]

# %%
x_train , x_test, y_train, y_test = TTS(x,y, test_size = 1/4, random_state = 42)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (3178, 15)
# (1060, 15)

# %%
scaler = StandardScaler()

# %%
x_train[num_feats] = scaler.fit_transform(x_train[num_feats])
x_test[num_feats] = scaler.fit_transform(x_test[num_feats])

# %% [markdown]
# ## Logistic Regression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)
score_train = model.score(x_train, y_train)
score_test = accuracy_score(y_test, y_pred)
print(f"Training score is: {round(score_train*100,2)}%",) 
print(f"Testing Accuracy is: {round(score_test*100,2)}%")
# Out:
# Training score is: 85.59%
# Testing Accuracy is: 85.19%

# %% [markdown]
# #### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score 
cm = confusion_matrix(y_test, y_pred) 
print("Confusion Matrix is:\n",cm)
# Out:
# Confusion Matrix is:
#  [[892   7]
#  [150  11]]

# %% [markdown]
# #### Classification Report

# %%
print("Classification Report:\n\n",classification_report(y_test,y_pred))
# Out:
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       899
#            1       0.61      0.07      0.12       161
#
#     accuracy                           0.85      1060
#    macro avg       0.73      0.53      0.52      1060
# weighted avg       0.82      0.85      0.80      1060

# %% [markdown]
# #### Plotting the confusion matrix

# %%
conf_matrix = pd.DataFrame(data = cm,  
                           columns = ['Predicted:0', 'Predicted:1'],  
                           index =['Actual:0', 'Actual:1']) 
plt.figure(figsize = (10, 6)) 
sns.heatmap(conf_matrix, annot = True, fmt = 'd', cmap = "Greens", linecolor="Blue", linewidths=1.5) 
plt.show()

# %% [markdown]
# ## Decision Tree

# %%
model = DecisionTreeClassifier(criterion='gini')
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(x_test)
score_train = model.score(x_train, y_train)
score_test = accuracy_score(y_test, y_pred)
print(f"Training score is: {round(score_train*100,2)}%",) 
print(f"Testing Accuracy is: {round(score_test*100,2)}%") ### Confusion Matrix
# Out:
# Training score is: 100.0%
# Testing Accuracy is: 75.94%

# %% [markdown]
# #### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score 
cm = confusion_matrix(y_test, y_pred) 
print("Confusion Matrix is:\n",cm)
# Out:
# Confusion Matrix is:
#  [[755 144]
#  [111  50]]

# %% [markdown]
# #### Classification Report

# %%
print("Classification Report:\n\n",classification_report(y_test,y_pred))
# Out:
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.87      0.84      0.86       899
#            1       0.26      0.31      0.28       161
#
#     accuracy                           0.76      1060
#    macro avg       0.56      0.58      0.57      1060
# weighted avg       0.78      0.76      0.77      1060

# %% [markdown]
# #### Plotting the confusion matrix

# %%
conf_matrix = pd.DataFrame(data = cm,  
                           columns = ['Predicted:0', 'Predicted:1'],  
                           index =['Actual:0', 'Actual:1']) 
plt.figure(figsize = (10, 6)) 
sns.heatmap(conf_matrix, annot = True, fmt = 'd', cmap = "Greens", linecolor="Blue", linewidths=1.5) 
plt.show()

# %% [markdown]
# ## Random Forest

# %%
model = RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(x_test)
score_train = model.score(x_train, y_train)
score_test = accuracy_score(y_test, y_pred)
print(f"Training score is: {round(score_train*100,2)}%",) 
print(f"Testing Accuracy is: {round(score_test*100,2)}%")
# Out:
# Training score is: 100.0%
# Testing Accuracy is: 85.57%

# %% [markdown]
# #### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score 
cm = confusion_matrix(y_test, y_pred) 
print("Confusion Matrix is:\n",cm)
# Out:
# Confusion Matrix is:
#  [[892   7]
#  [146  15]]

# %% [markdown]
# #### Classification Report

# %%
print("Classification Report:\n\n",classification_report(y_test,y_pred))
# Out:
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       899
#            1       0.68      0.09      0.16       161
#
#     accuracy                           0.86      1060
#    macro avg       0.77      0.54      0.54      1060
# weighted avg       0.83      0.86      0.81      1060

# %% [markdown]
# #### Plotting the confusion matrix

# %%
conf_matrix = pd.DataFrame(data = cm,  
                           columns = ['Predicted:0', 'Predicted:1'],  
                           index =['Actual:0', 'Actual:1']) 
plt.figure(figsize = (10, 6)) 
sns.heatmap(conf_matrix, annot = True, fmt = 'd', cmap = "Greens", linecolor="Blue", linewidths=1.5) 
plt.show()

# %% [markdown]
# ## Data Modelling - 2 (Over Sampling)

# %%
df = backup

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %% [markdown]
# ### Oversampling

# %%
pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.8.1-py3-none-any.whl (189 kB)
# Requirement already satisfied: joblib>=0.11 in c:\users\lenovo\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\lenovo\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.20.1)
# Requirement already satisfied: scikit-learn>=0.24 in c:\users\lenovo\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (0.24.1)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\lenovo\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.6.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn>=0.24->imbalanced-learn->imblearn) (2.1.0)
# Installing collected packages: imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.8.1 imblearn-0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE
x_new, y_new = SMOTE(random_state= 42,sampling_strategy= 0.9).fit_resample(x, y)

# %%
# Much better
y_new.value_counts()
# Out:
# 0    3595
# 1    3235
# Name: TenYearCHD, dtype: int64

# %%
x = x_new
y = y_new

# %%
plt.hist(y);
plt.title("TenYearCHD Distribution");

# %%
# concatenating x and y together
df = pd.concat([x,y], axis = 1)

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay    BPMeds  \
# 0        1   39   4.000000              0    0.000000  0.000000
# 1        0   46   2.000000              0    0.000000  0.000000
# 2        1   48   1.000000              1   20.000000  0.000000
# 3        0   61   3.000000              1   30.000000  0.000000
# 4        0   46   3.000000              1   23.000000  0.000000
# ...    ...  ...        ...            ...         ...       ...
# 6825     0   63   2.110074              0    0.000000  0.629975
# 6826     0   57   1.000000              1    3.201887  0.000000
# 6827     0   46   2.209985              0    0.000000  0.000000
# 6828     1   44   1.317983              1   42.046052  0.000000
# 6829     0   56   1.840538              1   13.622957  0.000000
#
#       prevalentStroke  prevalentHyp  diabetes     totChol       sysBP  \
# 0                   0             0         0  195.000000  106.000000
# 1                   0             0         0  250.000000  121.000000
# 2                   0             0         0  245.000000  127.500000
# 3                   0             1         0  225.000000  150.000000
# 4                   0             0         0  285.000000  130.000000
# ...               ...           ...       ...         ...         ...
# 6825                0             0         0  230.740049  161.220147
# 6826                0             1         0  246.293395  148.426651
# 6827                0             0         0  191.850223  124.740089
# 6828                0             0         0  220.451756  140.225878
# 6829                0             1         0  322.101344  149.564839
#
#           diaBP        BMI  heartRate     glucose  TenYearCHD
# 0     70.000000  26.970000  80.000000   77.000000           0
# 1     81.000000  28.730000  95.000000   76.000000           0
# 2     80.000000  25.340000  75.000000   70.000000           0
# 3     95.000000  28.580000  65.000000  103.000000           1
# 4     84.000000  23.100000  85.000000   85.000000           0
# ...         ...        ...        ...         ...         ...
# 6825  83.299755  25.248555  69.629975   62.039804           1
# 6826  82.651415  33.485037  73.651415   89.954246           1
# 6827  76.049926  24.933394  60.000000   81.963655           1
# 6828  90.682017  23.639847  72.953948   82.929160           1
# 6829  89.673629  26.008790  78.622957   91.217580           1
#
# [6830 rows x 16 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split as TTS
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
num_feats = ['age','education','cigsPerDay','totChol','sysBP','diaBP','BMI','heartRate','glucose']

# %%
df = df.sample(frac = 1) # Shuffling the records

# %%
x = df.iloc[:,0:-1]
y = df.iloc[:,-1]

# %%
x_train , x_test, y_train, y_test = TTS(x,y, test_size = 1/4, random_state = 42)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (5122, 15)
# (1708, 15)

# %%
scaler = StandardScaler()

# %%
x_train[num_feats] = scaler.fit_transform(x_train[num_feats])
x_test[num_feats] = scaler.transform(x_test[num_feats])

# %% [markdown]
# ## Logistic Regression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)
score_train = model.score(x_train, y_train)
score_test = accuracy_score(y_test, y_pred)
print(f"Training score is: {round(score_train*100,2)}%",) 
print(f"Testing Accuracy is: {round(score_test*100,2)}%")
# Out:
# Training score is: 66.91%
# Testing Accuracy is: 68.62%

# %% [markdown]
# #### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score 
cm = confusion_matrix(y_test, y_pred) 
print("Confusion Matrix is:\n",cm)
# Out:
# Confusion Matrix is:
#  [[670 237]
#  [299 502]]

# %% [markdown]
# #### Classification Report

# %%
print("Classification Report:\n\n",classification_report(y_test,y_pred))
# Out:
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.69      0.74      0.71       907
#            1       0.68      0.63      0.65       801
#
#     accuracy                           0.69      1708
#    macro avg       0.69      0.68      0.68      1708
# weighted avg       0.69      0.69      0.69      1708

# %% [markdown]
# #### Plotting the confusion matrix

# %%
conf_matrix = pd.DataFrame(data = cm,  
                           columns = ['Predicted:0', 'Predicted:1'],  
                           index =['Actual:0', 'Actual:1']) 
plt.figure(figsize = (10, 6)) 
sns.heatmap(conf_matrix, annot = True, fmt = 'd', cmap = "Greens", linecolor="Blue", linewidths=1.5) 
plt.show()

# %% [markdown]
# ## Decision Tree

# %%
model = DecisionTreeClassifier(criterion='gini')
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(x_test)
score_train = model.score(x_train, y_train)
score_test = accuracy_score(y_test, y_pred)
print(f"Training score is: {round(score_train*100,2)}%",) 
print(f"Testing Accuracy is: {round(score_test*100,2)}%") ### Confusion Matrix
# Out:
# Training score is: 100.0%
# Testing Accuracy is: 80.62%

# %% [markdown]
# #### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score 
cm = confusion_matrix(y_test, y_pred) 
print("Confusion Matrix is:\n",cm)
# Out:
# Confusion Matrix is:
#  [[726 181]
#  [150 651]]

# %% [markdown]
# #### Classification Report

# %%
print("Classification Report:\n\n",classification_report(y_test,y_pred))
# Out:
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.83      0.80      0.81       907
#            1       0.78      0.81      0.80       801
#
#     accuracy                           0.81      1708
#    macro avg       0.81      0.81      0.81      1708
# weighted avg       0.81      0.81      0.81      1708

# %% [markdown]
# #### Plotting the confusion matrix

# %%
conf_matrix = pd.DataFrame(data = cm,  
                           columns = ['Predicted:0', 'Predicted:1'],  
                           index =['Actual:0', 'Actual:1']) 
plt.figure(figsize = (10, 6)) 
sns.heatmap(conf_matrix, annot = True, fmt = 'd', cmap = "Greens", linecolor="Blue", linewidths=1.5) 
plt.show()

# %% [markdown]
# ## Random Forest

# %%
model = RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(x_test)
score_train = model.score(x_train, y_train)
score_test = accuracy_score(y_test, y_pred)
print(f"Training score is: {round(score_train*100,2)}%",) 
print(f"Testing Accuracy is: {round(score_test*100,2)}%")
# Out:
# Training score is: 100.0%
# Testing Accuracy is: 90.28%

# %% [markdown]
# #### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score 
cm = confusion_matrix(y_test, y_pred) 
print("Confusion Matrix is:\n",cm)
# Out:
# Confusion Matrix is:
#  [[861  46]
#  [120 681]]

# %% [markdown]
# #### Classification Report

# %%
print("Classification Report:\n\n",classification_report(y_test,y_pred))
# Out:
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91       907
#            1       0.94      0.85      0.89       801
#
#     accuracy                           0.90      1708
#    macro avg       0.91      0.90      0.90      1708
# weighted avg       0.91      0.90      0.90      1708

# %% [markdown]
# #### Plotting the confusion matrix

# %%
conf_matrix = pd.DataFrame(data = cm,  
                           columns = ['Predicted:0', 'Predicted:1'],  
                           index =['Actual:0', 'Actual:1']) 
plt.figure(figsize = (10, 6)) 
sns.heatmap(conf_matrix, annot = True, fmt = 'd', cmap = "Greens", linecolor="Blue", linewidths=1.5) 
plt.show()

# %% [markdown]
# Conclusion: Based on testing 3 different Algorithms twice,
# we concluded that Random Forest is the best one, with: <b><br> accuracy = 89%, recall = 83%, precision = 94%.

# %% [markdown]
# #  .. تم بحمد الله
